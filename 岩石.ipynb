# %%
# -*- coding: utf-8 -*-

# 代码2-6

import pandas as pd
basalt = pd.read_csv('./data/basalt_pre.csv')

#数据清洗
print("清洗前的数据的形状为：",basalt.shape)
basalt = basalt.loc[(basalt['SIO2(WT%)']>45)&(basalt['SIO2(WT%)']<55),:].copy()
basalt = basalt.loc[(basalt['TIO2(WT%)']>0.1),:].copy()
basalt = basalt.loc[(basalt['AL2O3(WT%)']>10)&(basalt['AL2O3(WT%)']<18),:].copy()
basalt = basalt.loc[(basalt['H2OT(WT%)']<7)|(basalt['H2OT(WT%)'].isnull()),:].copy()
basalt = basalt.loc[(basalt['LOI(WT%)']<7)|(basalt['LOI(WT%)'].isnull()),:].copy()
basalt = basalt.loc[(basalt['CO2(WT%)']<3)|(basalt['CO2(WT%)'].isnull()),:].copy()
basalt.drop(labels = ['H2OT(WT%)','CO2(WT%)','LOI(WT%)'],axis = 1,inplace = True)
print("清洗后的数据的形状为：",basalt.shape)

#查看每个属性的缺失值数量
print('各列的缺失值数量为：\n', basalt.isnull().sum())
print('去除缺失值前的数据的形状为：', basalt.shape)
print('去除缺失值后的数据的形状为：',basalt.dropna(axis = 0,how ='any').shape)
#删除缺失值
basalt = basalt.dropna(axis = 0,how ='any').copy()

#定义异常值处理函数
def outRange(Ser1):
    QL = Ser1.quantile(0.1)
    QU = Ser1.quantile(0.9)
    IQR = QU-QL
    #产生SettingWithCopyWarning
    Ser1.loc[Ser1>(QU+1.5*IQR)] = None
    Ser1.loc[Ser1<(QL-1.5*IQR)] = None

    return Ser1
#异常值处理
df = basalt.copy()
names = df.columns
for j in names[7:]:
    df[j] = outRange(df[j])
print('各列数据的异常值数量为：\n',df.isnull().sum())
df.dropna(axis = 0,how ='any',inplace=True)
print('去除异常值前的数据的形状为：', basalt.shape)
print('去除异常值后的数据的形状为：',df.shape)
#保存数据    
df.to_csv('./tmp/basalt.csv',index = False)
# Out:
# 清洗前的数据的形状为： (83362, 49)
# 清洗后的数据的形状为： (52408, 46)
# 各列的缺失值数量为：
#  TECTONIC SETTING      148
# LATITUDE                0
# LONGITUDE               0
# LAND OR SEA             0
# SAMPLE NAME             0
# SIO2(WT%)               0
# TIO2(WT%)               0
# AL2O3(WT%)              0
# Fe2O3T(WT%)          6672
# CAO(WT%)               10
# MGO(WT%)               10
# MNO(WT%)             1321
# K2O(WT%)               89
# NA2O(WT%)              54
# P2O5(WT%)            1475
# Fe2O3T                 29
# NI(PPM)             15048
# CU(PPM)             30333
# ZN(PPM)             28404
# SC(PPM)             26554
# V(PPM)              21009
# CR(PPM)             16628
# CO(PPM)             30650
# RB(PPM)             13192
# SR(PPM)             11452
# Y(PPM)              14243
# ZR(PPM)             12691
# NB(PPM)             16447
# CS(PPM)             38035
# BA(PPM)             14037
# LA(PPM)             20674
# CE(PPM)             20561
# PR(PPM)             33797
# ND(PPM)             24079
# SM(PPM)             25084
# EU(PPM)             25566
# GD(PPM)             31147
# TB(PPM)             28693
# DY(PPM)             31589
# HO(PPM)             33486
# ER(PPM)             31841
# TM(PPM)             35574
# YB(PPM)             25634
# LU(PPM)             27288
# HF(PPM)             29476
# TA(PPM)             31018
# dtype: int64
# 去除缺失值前的数据的形状为： (52408, 46)
# 去除缺失值后的数据的形状为： (3629, 46)
# 各列数据的异常值数量为：
#  TECTONIC SETTING      0
# LATITUDE              0
# LONGITUDE             0
# LAND OR SEA           0
# SAMPLE NAME           0
# SIO2(WT%)             0
# TIO2(WT%)             0
# AL2O3(WT%)            0
# Fe2O3T(WT%)           7
# CAO(WT%)              6
# MGO(WT%)              5
# MNO(WT%)             53
# K2O(WT%)             34
# NA2O(WT%)             0
# P2O5(WT%)             4
# Fe2O3T                3
# NI(PPM)              14
# CU(PPM)              44
# ZN(PPM)              34
# SC(PPM)               3
# V(PPM)               12
# CR(PPM)              41
# CO(PPM)              27
# RB(PPM)              37
# SR(PPM)               5
# Y(PPM)               22
# ZR(PPM)              12
# NB(PPM)               5
# CS(PPM)             140
# BA(PPM)              36
# LA(PPM)               6
# CE(PPM)               8
# PR(PPM)              11
# ND(PPM)              10
# SM(PPM)              11
# EU(PPM)              10
# GD(PPM)              10
# TB(PPM)              15
# DY(PPM)              15
# HO(PPM)              20
# ER(PPM)              17
# TM(PPM)              36
# YB(PPM)              17
# LU(PPM)              15
# HF(PPM)              20
# TA(PPM)               4
# dtype: int64
# 去除异常值前的数据的形状为： (3629, 46)
# 去除异常值后的数据的形状为： (3213, 46)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1>(QU+1.5*IQR)] = None
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19024\3353616539.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ser1.loc[Ser1<(QL-1.5*IQR)] = None
